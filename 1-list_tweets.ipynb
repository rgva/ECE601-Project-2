# %%
import tweepy
import webbrowser
import time
import pandas as pd
#Authentication script
consumer_key = ""
consumer_secret = ""
callback_uri = 'oob'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
redirect_url = auth.get_authorization_url()
print(redirect_url)
webbrowser.open(redirect_url)
user_pint_input = input("What is the pin value? ") #User pin input
auth.get_access_token(user_pint_input)
print(auth.access_token, auth.access_token_secret) 
api = tweepy.API(auth)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=lIyRzgAAAAABh_cbAAABg8IVfTY
# 1578938889980592128-IDytxONaDyRGcd3A7aablBpA3ZRM6r ycvwdMEIfE6P8plFdPpk934VNasb5c09K33dddDlRmd9Q

# %%
#Grab timeline from @UFC
timeline = api.home_timeline()

# %%
columns = set()
allowed_types = [str, int]
tweets_data = [ ]

for status in timeline:
    #print(status.text)
    #print(type(vars(status)))
    status_dict = dict(vars(status))
    keys = vars(status).keys()
    single_tweet_data = {}
    for k in keys:
        try:
            v_type = type(status_dict[k])
        except:
            v_type = None
        if v_type != None:
            if v_type in allowed_types:
                single_tweet_data[k] = status_dict[k]
                columns.add(k)
    tweets_data.append(single_tweet_data)

header_cols = list(columns)

# %%
tweets_data
# Out:
# [{'id': 1579341439619985409,
#   'id_str': '1579341439619985409',
#   'text': 'Who leaves Abu Dhabi as lightweight champion - @CharlesDoBronxs or @MakhachevMMA? 🏆\n\n[ #UFC280 Countdown airs Octob… https://t.co/DN8JaqFTlk',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 255,
#   'favorite_count': 2194,
#   'lang': 'en'},
#  {'id': 1579291525552304133,
#   'id_str': '1579291525552304133',
#   'text': 'Enjoy the show!',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'in_reply_to_status_id': 1579291076640509954,
#   'in_reply_to_status_id_str': '1579291076640509954',
#   'in_reply_to_user_id': 1578938889980592128,
#   'in_reply_to_user_id_str': '1578938889980592128',
#   'in_reply_to_screen_name': 'Rgva_ECE',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1579291489288396805,
#   'id_str': '1579291489288396805',
# ...

# %%
df = pd.DataFrame(tweets_data, columns=header_cols)
df.head()
# Out:
#   in_reply_to_screen_name                   id           source  \
# 0                     NaN  1579341439619985409  Twitter Web App
# 1                Rgva_ECE  1579291525552304133  Twitter Web App
# 2                Rgva_ECE  1579291489288396805  Twitter Web App
# 3                Rgva_ECE  1579291343159193602  Twitter Web App
# 4                Rgva_ECE  1579291076640509954  Twitter Web App
#
#    retweet_count  in_reply_to_status_id in_reply_to_status_id_str  \
# 0            255                    NaN                       NaN
# 1              0           1.579291e+18       1579291076640509954
# 2              0           1.579291e+18       1579291076640509954
# 3              0           1.579291e+18       1579291076640509954
# 4              0           1.579291e+18       1579290996235726848
#
#    in_reply_to_user_id                  source_url lang  \
# 0                  NaN  https://mobile.twitter.com   en
# 1         1.578939e+18  https://mobile.twitter.com   en
# ...

# %%
df.to_csv (r'C:\Users\Roman Velez Alicea\Desktop\export_dataframe.csv', index = False, header=True)
